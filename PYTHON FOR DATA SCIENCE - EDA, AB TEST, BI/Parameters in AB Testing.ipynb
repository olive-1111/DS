# %%
alpha = 0.05 # 5%
print("Alpha: siginificance level is:", alpha)

delta = 0.1 #
print("Delta: minimum detectable effect is:", delta)
# Out:
# Alpha: siginificance level is: 0.05
# Delta: minimum detectable effect is: 0.1

# %%
import pandas as pd
df_ab_test = pd.read_csv(r"C:\Users\asus\Documents\CaseStudies-main\AB Testing\ab_test_click_data.csv")

# calculating the total number of clicks per group by summing 1's
X_con = df_ab_test.groupby("group")["click"].sum().loc["con"]
X_exp = df_ab_test.groupby("group")["click"].sum().loc["exp"]

# print this visibility
print(df_ab_test.groupby("group")["click"].sum())
print("Number of clicks in Control: ", X_con)
print("Number of clicks in Experimental: ", X_exp)
# Out:
# group
# con    1989
# exp    6116
# Name: click, dtype: int64
# Number of clicks in Control:  1989
# Number of clicks in Experimental:  6116
