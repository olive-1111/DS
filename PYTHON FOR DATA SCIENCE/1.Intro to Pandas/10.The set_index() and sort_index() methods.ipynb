# %%
import pandas as pd
import numpy as np
import random

df_exams = pd.read_csv(r"D:\python-for-data-science-main\02.Intro to Pandas\StudentsPerformance.csv")
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
new_index = np.arange(0, 1000)

# %%
random.shuffle(new_index)

# %%
df_exams['new_index'] = new_index
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      new_index
# 0          543
# 1          456
# 2           94
# 3          448
# 4          707
# ..         ...
# 995        244
# 996        359
# 997        369
# 998        408
# 999        623
#
# [1000 rows x 9 columns]

# %%
df_exams.set_index('new_index', inplace=True)
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 543        female        group B           bachelor's degree      standard
# 456        female        group C                some college      standard
# 94         female        group B             master's degree      standard
# 448          male        group A          associate's degree  free/reduced
# 707          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 244        female        group E             master's degree      standard
# 359          male        group C                 high school  free/reduced
# 369        female        group C                 high school  free/reduced
# 408        female        group D                some college      standard
# 623        female        group D                some college  free/reduced
#
#           test preparation course  math score  reading score  writing score
# new_index
# 543                          none          72             72             74
# 456                     completed          69             90             88
# 94                           none          90             95             93
# 448                          none          47             57             44
# 707                          none          76             78             75
# ...                           ...         ...            ...            ...
# 244                     completed          88             99             95
# 359                          none          62             55             55
# 369                     completed          59             71             65
# 408                     completed          68             78             77
# 623                          none          77             86             86
#
# [1000 rows x 8 columns]

# %%
df_exams.sort_index()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      new_index
# 0          543
# 1          456
# 2           94
# 3          448
# 4          707
# ..         ...
# 995        244
# 996        359
# 997        369
# 998        408
# 999        623
#
# [1000 rows x 9 columns]

# %%
df_exams.sort_index(ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999  female        group D                some college  free/reduced
# 998  female        group D                some college      standard
# 997  female        group C                 high school  free/reduced
# 996    male        group C                 high school  free/reduced
# 995  female        group E             master's degree      standard
# ..      ...            ...                         ...           ...
# 4      male        group C                some college      standard
# 3      male        group A          associate's degree  free/reduced
# 2    female        group B             master's degree      standard
# 1    female        group C                some college      standard
# 0    female        group B           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 999                    none          77             86             86
# 998               completed          68             78             77
# 997               completed          59             71             65
# 996                    none          62             55             55
# 995               completed          88             99             95
# ..                      ...         ...            ...            ...
# 4                      none          76             78             75
# 3                      none          47             57             44
# 2                      none          90             95             93
# 1                 completed          69             90             88
# 0                      none          72             72             74
#
#      new_index
# 999        623
# 998        408
# 997        369
# 996        359
# 995        244
# ..         ...
# 4          707
# 3          448
# 2           94
# 1          456
# 0          543
#
# [1000 rows x 9 columns]

# %%
df_exams.sort_index(ascending=False, inplace=True)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999  female        group D                some college  free/reduced
# 998  female        group D                some college      standard
# 997  female        group C                 high school  free/reduced
# 996    male        group C                 high school  free/reduced
# 995  female        group E             master's degree      standard
# ..      ...            ...                         ...           ...
# 4      male        group C                some college      standard
# 3      male        group A          associate's degree  free/reduced
# 2    female        group B             master's degree      standard
# 1    female        group C                some college      standard
# 0    female        group B           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 999                    none          77             86             86
# 998               completed          68             78             77
# 997               completed          59             71             65
# 996                    none          62             55             55
# 995               completed          88             99             95
# ..                      ...         ...            ...            ...
# 4                      none          76             78             75
# 3                      none          47             57             44
# 2                      none          90             95             93
# 1                 completed          69             90             88
# 0                      none          72             72             74
#
#      new_index
# 999        623
# 998        408
# 997        369
# 996        359
# 995        244
# ..         ...
# 4          707
# 3          448
# 2           94
# 1          456
# 0          543
#
# [1000 rows x 9 columns]
