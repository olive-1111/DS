# %%
import pandas as pd

df_movies = pd.read_csv(r"D:\python-for-data-science-main\09.Merging and Concatenating DataFrames\IMDb movies.csv\IMDb movies.csv", low_memory=False)
df_movies

df1 = pd.DataFrame({'id':['A', 'B', 'C', 'D'],
                   'age':[30, 23, 25, 22 ]})

df2 = pd.DataFrame({'id':['C', 'D', 'E', 'F'],
                    'job':['Doctor', 'Statistician', 
                           'Accountant', 'Developer']})

df1
# Out:
#   id  age
# 0  A   30
# 1  B   23
# 2  C   25
# 3  D   22

# %%
df2
# Out:
#   id           job
# 0  C        Doctor
# 1  D  Statistician
# 2  E    Accountant
# 3  F     Developer

# %%
df_inner_join = df1.merge(df2, on='id', how='inner')
df_inner_join
# Out:
#   id  age           job
# 0  C   25        Doctor
# 1  D   22  Statistician

# %%
print(df1.shape)
print(df2.shape)
print(df_inner_join.shape)
# Out:
# (4, 2)
# (4, 2)
# (2, 3)

# %%
df_movies
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ...  \
# 0                          Alexander Black  ...
# 1                             Charles Tait  ...
# 2                                Urban Gad  ...
# 3                       Charles L. Gaskill  ...
# 4      Francesco Bertolini, Adolfo Padovan  ...
# ...                                    ...  ...
# 85850               Ludovic Colbeau-Justin  ...
# 85851                      Johan Nijenhuis  ...
# 85852                      Vineesh Aaradya  ...
# 85853                    Ahmet Faik Akinci  ...
# 85854                            Laura Jou  ...
#
#                                                   actors  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# ...                                                  ...
# 85850  Dany Boon, Philippe Katerine, Anne Serra, Samu...
# 85851  Herman Finkers, Johanna ter Steege, Leonie ter...
# 85852  Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# 85853  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# 85854  Maria Morera Colomer, Biel Rossell Pelfort, Is...
#
#                                              description avg_vote votes  \
# 0      The adventures of a female reporter in the 1890s.      5.9   154
# 1      True story of notorious Australian outlaw Ned ...      6.1   589
# 2      Two men of high rank are both wooing the beaut...      5.8   188
# 3      The fabled queen of Egypt's affair with Roman ...      5.2   446
# 4      Loosely adapted from Dante's Divine Comedy and...      7.0  2237
# ...                                                  ...      ...   ...
# 85850  A psychiatric hospital patient pretends to be ...      5.3   398
# 85851  A middle-aged veterinary surgeon believes his ...      7.7   724
# 85852                                                NaN      7.9   265
# 85853                                                NaN      6.4   194
# 85854  Pep, a 13-year-old boy, is in love with a girl...      6.7   102
#
#         budget  usa_gross_income worlwide_gross_income metascore  \
# 0          NaN               NaN                   NaN       NaN
# 1       $ 2250               NaN                   NaN       NaN
# 2          NaN               NaN                   NaN       NaN
# 3      $ 45000               NaN                   NaN       NaN
# 4          NaN               NaN                   NaN       NaN
# ...        ...               ...                   ...       ...
# 85850      NaN               NaN             $ 3507171       NaN
# 85851      NaN               NaN             $ 7299062       NaN
# 85852      NaN               NaN                   NaN       NaN
# 85853      NaN               NaN                $ 2833       NaN
# 85854      NaN               NaN               $ 59794       NaN
#
#       reviews_from_users  reviews_from_critics
# 0                    1.0                   2.0
# 1                    7.0                   7.0
# 2                    5.0                   2.0
# 3                   25.0                   3.0
# 4                   31.0                  14.0
# ...                  ...                   ...
# 85850                NaN                   4.0
# 85851                6.0                   4.0
# 85852                NaN                   NaN
# 85853                NaN                   NaN
# 85854                NaN                   2.0
#
# [85855 rows x 22 columns]

# %%
df_ratings = pd.read_csv(r"D:\python-for-data-science-main\09.Merging and Concatenating DataFrames\IMDb ratings.csv\IMDb ratings.csv")
df_ratings
# Out:
#       imdb_title_id  weighted_average_vote  total_votes  mean_vote  \
# 0         tt0000009                    5.9          154        5.9
# 1         tt0000574                    6.1          589        6.3
# 2         tt0001892                    5.8          188        6.0
# 3         tt0002101                    5.2          446        5.3
# 4         tt0002130                    7.0         2237        6.9
# ...             ...                    ...          ...        ...
# 85850     tt9908390                    5.3          398        5.5
# 85851     tt9911196                    7.7          724        7.9
# 85852     tt9911774                    7.9          265        7.8
# 85853     tt9914286                    6.4          194        9.4
# 85854     tt9914942                    6.7          102        6.8
#
#        median_vote  votes_10  votes_9  votes_8  votes_7  votes_6  ...  \
# 0              6.0        12        4       10       43       28  ...
# 1              6.0        57       18       58      137      139  ...
# 2              6.0         6        6       17       44       52  ...
# 3              5.0        15        8       16       62       98  ...
# 4              7.0       210      225      436      641      344  ...
# ...            ...       ...      ...      ...      ...      ...  ...
# 85850          6.0        13        9       26       65      104  ...
# 85851          8.0        65      139      288      170       42  ...
# 85852          8.0        63       29       61       61       31  ...
# 85853         10.0       176        0        2        2        1  ...
# 85854          7.0         4        4       21       35       27  ...
#
#        females_30age_avg_vote  females_30age_votes  females_45age_avg_vote  \
# 0                         5.7                 13.0                     4.5
# 1                         6.2                 23.0                     6.6
# 2                         5.8                  4.0                     6.8
# 3                         5.5                 14.0                     6.1
# 4                         7.3                 82.0                     7.4
# ...                       ...                  ...                     ...
# 85850                     5.7                 11.0                     5.0
# 85851                     8.0                 47.0                     7.3
# 85852                     NaN                  NaN                     NaN
# 85853                     NaN                  NaN                     7.0
# 85854                     6.8                  4.0                     7.5
#
#        females_45age_votes  top1000_voters_rating  top1000_voters_votes  \
# 0                      4.0                    5.7                  34.0
# 1                     14.0                    6.4                  66.0
# 2                      7.0                    5.4                  32.0
# 3                     21.0                    4.9                  57.0
# 4                     77.0                    6.9                 139.0
# ...                    ...                    ...                   ...
# 85850                  2.0                    5.5                  12.0
# 85851                 30.0                    7.0                   6.0
# 85852                  NaN                    1.0                   1.0
# 85853                  1.0                    4.0                   3.0
# 85854                  4.0                    7.0                   4.0
#
#        us_voters_rating  us_voters_votes  non_us_voters_rating  \
# 0                   6.4             51.0                   6.0
# 1                   6.0             96.0                   6.2
# 2                   6.2             31.0                   5.9
# 3                   5.5            207.0                   4.7
# 4                   7.0            488.0                   7.0
# ...                 ...              ...                   ...
# 85850               6.3             22.0                   5.3
# 85851               6.8             13.0                   7.7
# 85852               NaN              NaN                   2.0
# 85853               1.7              5.0                   5.8
# 85854               6.7             13.0                   6.7
#
#        non_us_voters_votes
# 0                     70.0
# 1                    331.0
# 2                    123.0
# 3                    105.0
# 4                   1166.0
# ...                    ...
# 85850                214.0
# 85851                388.0
# 85852                  2.0
# 85853                  5.0
# 85854                 60.0
#
# [85855 rows x 49 columns]

# %%
df_movies.merge(df_ratings, on='imdb_title_id', how='inner')
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ... females_30age_avg_vote  \
# 0                          Alexander Black  ...                    5.7
# 1                             Charles Tait  ...                    6.2
# 2                                Urban Gad  ...                    5.8
# 3                       Charles L. Gaskill  ...                    5.5
# 4      Francesco Bertolini, Adolfo Padovan  ...                    7.3
# ...                                    ...  ...                    ...
# 85850               Ludovic Colbeau-Justin  ...                    5.7
# 85851                      Johan Nijenhuis  ...                    8.0
# 85852                      Vineesh Aaradya  ...                    NaN
# 85853                    Ahmet Faik Akinci  ...                    NaN
# 85854                            Laura Jou  ...                    6.8
#
#       females_30age_votes females_45age_avg_vote females_45age_votes  \
# 0                    13.0                    4.5                 4.0
# 1                    23.0                    6.6                14.0
# 2                     4.0                    6.8                 7.0
# 3                    14.0                    6.1                21.0
# 4                    82.0                    7.4                77.0
# ...                   ...                    ...                 ...
# 85850                11.0                    5.0                 2.0
# 85851                47.0                    7.3                30.0
# 85852                 NaN                    NaN                 NaN
# 85853                 NaN                    7.0                 1.0
# 85854                 4.0                    7.5                 4.0
#
#        top1000_voters_rating  top1000_voters_votes us_voters_rating  \
# 0                        5.7                  34.0              6.4
# 1                        6.4                  66.0              6.0
# 2                        5.4                  32.0              6.2
# 3                        4.9                  57.0              5.5
# 4                        6.9                 139.0              7.0
# ...                      ...                   ...              ...
# 85850                    5.5                  12.0              6.3
# 85851                    7.0                   6.0              6.8
# 85852                    1.0                   1.0              NaN
# 85853                    4.0                   3.0              1.7
# 85854                    7.0                   4.0              6.7
#
#       us_voters_votes non_us_voters_rating  non_us_voters_votes
# 0                51.0                  6.0                 70.0
# 1                96.0                  6.2                331.0
# 2                31.0                  5.9                123.0
# 3               207.0                  4.7                105.0
# 4               488.0                  7.0               1166.0
# ...               ...                  ...                  ...
# 85850            22.0                  5.3                214.0
# 85851            13.0                  7.7                388.0
# 85852             NaN                  2.0                  2.0
# 85853             5.0                  5.8                  5.0
# 85854            13.0                  6.7                 60.0
#
# [85855 rows x 70 columns]

# %%
df_movies.merge(df_ratings, on='imdb_title_id')
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ... females_30age_avg_vote  \
# 0                          Alexander Black  ...                    5.7
# 1                             Charles Tait  ...                    6.2
# 2                                Urban Gad  ...                    5.8
# 3                       Charles L. Gaskill  ...                    5.5
# 4      Francesco Bertolini, Adolfo Padovan  ...                    7.3
# ...                                    ...  ...                    ...
# 85850               Ludovic Colbeau-Justin  ...                    5.7
# 85851                      Johan Nijenhuis  ...                    8.0
# 85852                      Vineesh Aaradya  ...                    NaN
# 85853                    Ahmet Faik Akinci  ...                    NaN
# 85854                            Laura Jou  ...                    6.8
#
#       females_30age_votes females_45age_avg_vote females_45age_votes  \
# 0                    13.0                    4.5                 4.0
# 1                    23.0                    6.6                14.0
# 2                     4.0                    6.8                 7.0
# 3                    14.0                    6.1                21.0
# 4                    82.0                    7.4                77.0
# ...                   ...                    ...                 ...
# 85850                11.0                    5.0                 2.0
# 85851                47.0                    7.3                30.0
# 85852                 NaN                    NaN                 NaN
# 85853                 NaN                    7.0                 1.0
# 85854                 4.0                    7.5                 4.0
#
#        top1000_voters_rating  top1000_voters_votes us_voters_rating  \
# 0                        5.7                  34.0              6.4
# 1                        6.4                  66.0              6.0
# 2                        5.4                  32.0              6.2
# 3                        4.9                  57.0              5.5
# 4                        6.9                 139.0              7.0
# ...                      ...                   ...              ...
# 85850                    5.5                  12.0              6.3
# 85851                    7.0                   6.0              6.8
# 85852                    1.0                   1.0              NaN
# 85853                    4.0                   3.0              1.7
# 85854                    7.0                   4.0              6.7
#
#       us_voters_votes non_us_voters_rating  non_us_voters_votes
# 0                51.0                  6.0                 70.0
# 1                96.0                  6.2                331.0
# 2                31.0                  5.9                123.0
# 3               207.0                  4.7                105.0
# 4               488.0                  7.0               1166.0
# ...               ...                  ...                  ...
# 85850            22.0                  5.3                214.0
# 85851            13.0                  7.7                388.0
# 85852             NaN                  2.0                  2.0
# 85853             5.0                  5.8                  5.0
# 85854            13.0                  6.7                 60.0
#
# [85855 rows x 70 columns]

# %%
pd.merge(df_movies, df_ratings, on='imdb_title_id')
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ... females_30age_avg_vote  \
# 0                          Alexander Black  ...                    5.7
# 1                             Charles Tait  ...                    6.2
# 2                                Urban Gad  ...                    5.8
# 3                       Charles L. Gaskill  ...                    5.5
# 4      Francesco Bertolini, Adolfo Padovan  ...                    7.3
# ...                                    ...  ...                    ...
# 85850               Ludovic Colbeau-Justin  ...                    5.7
# 85851                      Johan Nijenhuis  ...                    8.0
# 85852                      Vineesh Aaradya  ...                    NaN
# 85853                    Ahmet Faik Akinci  ...                    NaN
# 85854                            Laura Jou  ...                    6.8
#
#       females_30age_votes females_45age_avg_vote females_45age_votes  \
# 0                    13.0                    4.5                 4.0
# 1                    23.0                    6.6                14.0
# 2                     4.0                    6.8                 7.0
# 3                    14.0                    6.1                21.0
# 4                    82.0                    7.4                77.0
# ...                   ...                    ...                 ...
# 85850                11.0                    5.0                 2.0
# 85851                47.0                    7.3                30.0
# 85852                 NaN                    NaN                 NaN
# 85853                 NaN                    7.0                 1.0
# 85854                 4.0                    7.5                 4.0
#
#        top1000_voters_rating  top1000_voters_votes us_voters_rating  \
# 0                        5.7                  34.0              6.4
# 1                        6.4                  66.0              6.0
# 2                        5.4                  32.0              6.2
# 3                        4.9                  57.0              5.5
# 4                        6.9                 139.0              7.0
# ...                      ...                   ...              ...
# 85850                    5.5                  12.0              6.3
# 85851                    7.0                   6.0              6.8
# 85852                    1.0                   1.0              NaN
# 85853                    4.0                   3.0              1.7
# 85854                    7.0                   4.0              6.7
#
#       us_voters_votes non_us_voters_rating  non_us_voters_votes
# 0                51.0                  6.0                 70.0
# 1                96.0                  6.2                331.0
# 2                31.0                  5.9                123.0
# 3               207.0                  4.7                105.0
# 4               488.0                  7.0               1166.0
# ...               ...                  ...                  ...
# 85850            22.0                  5.3                214.0
# 85851            13.0                  7.7                388.0
# 85852             NaN                  2.0                  2.0
# 85853             5.0                  5.8                  5.0
# 85854            13.0                  6.7                 60.0
#
# [85855 rows x 70 columns]

# %%
# outer join (full join)

df1.merge(df2, on='id', how='outer')
# Out:
#   id   age           job
# 0  A  30.0           NaN
# 1  B  23.0           NaN
# 2  C  25.0        Doctor
# 3  D  22.0  Statistician
# 4  E   NaN    Accountant
# 5  F   NaN     Developer

# %%
df_movies.merge(df_ratings, on='imdb_title_id', how='outer')
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ... females_30age_avg_vote  \
# 0                          Alexander Black  ...                    5.7
# 1                             Charles Tait  ...                    6.2
# 2                                Urban Gad  ...                    5.8
# 3                       Charles L. Gaskill  ...                    5.5
# 4      Francesco Bertolini, Adolfo Padovan  ...                    7.3
# ...                                    ...  ...                    ...
# 85850               Ludovic Colbeau-Justin  ...                    5.7
# 85851                      Johan Nijenhuis  ...                    8.0
# 85852                      Vineesh Aaradya  ...                    NaN
# 85853                    Ahmet Faik Akinci  ...                    NaN
# 85854                            Laura Jou  ...                    6.8
#
#       females_30age_votes females_45age_avg_vote females_45age_votes  \
# 0                    13.0                    4.5                 4.0
# 1                    23.0                    6.6                14.0
# 2                     4.0                    6.8                 7.0
# 3                    14.0                    6.1                21.0
# 4                    82.0                    7.4                77.0
# ...                   ...                    ...                 ...
# 85850                11.0                    5.0                 2.0
# 85851                47.0                    7.3                30.0
# 85852                 NaN                    NaN                 NaN
# 85853                 NaN                    7.0                 1.0
# 85854                 4.0                    7.5                 4.0
#
#        top1000_voters_rating  top1000_voters_votes us_voters_rating  \
# 0                        5.7                  34.0              6.4
# 1                        6.4                  66.0              6.0
# 2                        5.4                  32.0              6.2
# 3                        4.9                  57.0              5.5
# 4                        6.9                 139.0              7.0
# ...                      ...                   ...              ...
# 85850                    5.5                  12.0              6.3
# 85851                    7.0                   6.0              6.8
# 85852                    1.0                   1.0              NaN
# 85853                    4.0                   3.0              1.7
# 85854                    7.0                   4.0              6.7
#
#       us_voters_votes non_us_voters_rating  non_us_voters_votes
# 0                51.0                  6.0                 70.0
# 1                96.0                  6.2                331.0
# 2                31.0                  5.9                123.0
# 3               207.0                  4.7                105.0
# 4               488.0                  7.0               1166.0
# ...               ...                  ...                  ...
# 85850            22.0                  5.3                214.0
# 85851            13.0                  7.7                388.0
# 85852             NaN                  2.0                  2.0
# 85853             5.0                  5.8                  5.0
# 85854            13.0                  6.7                 60.0
#
# [85855 rows x 70 columns]

# %%
df1.merge(df2, on='id', how='outer', indicator=True)
# Out:
#   id   age           job      _merge
# 0  A  30.0           NaN   left_only
# 1  B  23.0           NaN   left_only
# 2  C  25.0        Doctor        both
# 3  D  22.0  Statistician        both
# 4  E   NaN    Accountant  right_only
# 5  F   NaN     Developer  right_only

# %%
df1.merge(df2, on='id', how='outer'
          , indicator=True).query("_merge=='left_only' or _merge=='right_only'")
# Out:
#   id   age         job      _merge
# 0  A  30.0         NaN   left_only
# 1  B  23.0         NaN   left_only
# 4  E   NaN  Accountant  right_only
# 5  F   NaN   Developer  right_only

# %%
df_movies.merge(df_ratings, on='imdb_title_id', how='outer')
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ... females_30age_avg_vote  \
# 0                          Alexander Black  ...                    5.7
# 1                             Charles Tait  ...                    6.2
# 2                                Urban Gad  ...                    5.8
# 3                       Charles L. Gaskill  ...                    5.5
# 4      Francesco Bertolini, Adolfo Padovan  ...                    7.3
# ...                                    ...  ...                    ...
# 85850               Ludovic Colbeau-Justin  ...                    5.7
# 85851                      Johan Nijenhuis  ...                    8.0
# 85852                      Vineesh Aaradya  ...                    NaN
# 85853                    Ahmet Faik Akinci  ...                    NaN
# 85854                            Laura Jou  ...                    6.8
#
#       females_30age_votes females_45age_avg_vote females_45age_votes  \
# 0                    13.0                    4.5                 4.0
# 1                    23.0                    6.6                14.0
# 2                     4.0                    6.8                 7.0
# 3                    14.0                    6.1                21.0
# 4                    82.0                    7.4                77.0
# ...                   ...                    ...                 ...
# 85850                11.0                    5.0                 2.0
# 85851                47.0                    7.3                30.0
# 85852                 NaN                    NaN                 NaN
# 85853                 NaN                    7.0                 1.0
# 85854                 4.0                    7.5                 4.0
#
#        top1000_voters_rating  top1000_voters_votes us_voters_rating  \
# 0                        5.7                  34.0              6.4
# 1                        6.4                  66.0              6.0
# 2                        5.4                  32.0              6.2
# 3                        4.9                  57.0              5.5
# 4                        6.9                 139.0              7.0
# ...                      ...                   ...              ...
# 85850                    5.5                  12.0              6.3
# 85851                    7.0                   6.0              6.8
# 85852                    1.0                   1.0              NaN
# 85853                    4.0                   3.0              1.7
# 85854                    7.0                   4.0              6.7
#
#       us_voters_votes non_us_voters_rating  non_us_voters_votes
# 0                51.0                  6.0                 70.0
# 1                96.0                  6.2                331.0
# 2                31.0                  5.9                123.0
# 3               207.0                  4.7                105.0
# 4               488.0                  7.0               1166.0
# ...               ...                  ...                  ...
# 85850            22.0                  5.3                214.0
# 85851            13.0                  7.7                388.0
# 85852             NaN                  2.0                  2.0
# 85853             5.0                  5.8                  5.0
# 85854            13.0                  6.7                 60.0
#
# [85855 rows x 70 columns]

# %%
df_movies.merge(df_ratings, on='imdb_title_id', how='outer', indicator=True)
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ... females_30age_votes  \
# 0                          Alexander Black  ...                13.0
# 1                             Charles Tait  ...                23.0
# 2                                Urban Gad  ...                 4.0
# 3                       Charles L. Gaskill  ...                14.0
# 4      Francesco Bertolini, Adolfo Padovan  ...                82.0
# ...                                    ...  ...                 ...
# 85850               Ludovic Colbeau-Justin  ...                11.0
# 85851                      Johan Nijenhuis  ...                47.0
# 85852                      Vineesh Aaradya  ...                 NaN
# 85853                    Ahmet Faik Akinci  ...                 NaN
# 85854                            Laura Jou  ...                 4.0
#
#       females_45age_avg_vote females_45age_votes top1000_voters_rating  \
# 0                        4.5                 4.0                   5.7
# 1                        6.6                14.0                   6.4
# 2                        6.8                 7.0                   5.4
# 3                        6.1                21.0                   4.9
# 4                        7.4                77.0                   6.9
# ...                      ...                 ...                   ...
# 85850                    5.0                 2.0                   5.5
# 85851                    7.3                30.0                   7.0
# 85852                    NaN                 NaN                   1.0
# 85853                    7.0                 1.0                   4.0
# 85854                    7.5                 4.0                   7.0
#
#        top1000_voters_votes  us_voters_rating us_voters_votes  \
# 0                      34.0               6.4            51.0
# 1                      66.0               6.0            96.0
# 2                      32.0               6.2            31.0
# 3                      57.0               5.5           207.0
# 4                     139.0               7.0           488.0
# ...                     ...               ...             ...
# 85850                  12.0               6.3            22.0
# 85851                   6.0               6.8            13.0
# 85852                   1.0               NaN             NaN
# 85853                   3.0               1.7             5.0
# 85854                   4.0               6.7            13.0
#
#       non_us_voters_rating non_us_voters_votes  _merge
# 0                      6.0                70.0    both
# 1                      6.2               331.0    both
# 2                      5.9               123.0    both
# 3                      4.7               105.0    both
# 4                      7.0              1166.0    both
# ...                    ...                 ...     ...
# 85850                  5.3               214.0    both
# 85851                  7.7               388.0    both
# 85852                  2.0                 2.0    both
# 85853                  5.8                 5.0    both
# 85854                  6.7                60.0    both
#
# [85855 rows x 71 columns]

# %%
df_movies.merge(df_ratings, on='imdb_title_id', 
               how='outer', indicator=True).query("_merge=='left_only' or _merge=='right_only'")
# Out:
# Empty DataFrame
# Columns: [imdb_title_id, title, original_title, year, date_published, genre, duration, country, language, director, writer, production_company, actors, description, avg_vote, votes, budget, usa_gross_income, worlwide_gross_income, metascore, reviews_from_users, reviews_from_critics, weighted_average_vote, total_votes, mean_vote, median_vote, votes_10, votes_9, votes_8, votes_7, votes_6, votes_5, votes_4, votes_3, votes_2, votes_1, allgenders_0age_avg_vote, allgenders_0age_votes, allgenders_18age_avg_vote, allgenders_18age_votes, allgenders_30age_avg_vote, allgenders_30age_votes, allgenders_45age_avg_vote, allgenders_45age_votes, males_allages_avg_vote, males_allages_votes, males_0age_avg_vote, males_0age_votes, males_18age_avg_vote, males_18age_votes, males_30age_avg_vote, males_30age_votes, males_45age_avg_vote, males_45age_votes, females_allages_avg_vote, females_allages_votes, females_0age_avg_vote, females_0age_votes, females_18age_avg_vote, females_18age_votes, females_30age_avg_vote, females_30age_votes, females_45age_avg_vote, females_45age_votes, top1000_voters_rating, top1000_voters_votes, us_voters_rating, us_voters_votes, non_us_voters_rating, non_us_voters_votes, _merge]
# Index: []
#
# [0 rows x 71 columns]

# %%
df1.merge(df2, on='id', how='left')
# Out:
#   id  age           job
# 0  A   30           NaN
# 1  B   23           NaN
# 2  C   25        Doctor
# 3  D   22  Statistician

# %%
df_movies = pd.read_csv(r"D:\python-for-data-science-main\09.Merging and Concatenating DataFrames\IMDb movies.csv\IMDb movies.csv", low_memory=False)

df_movies_sample = df_movies.sample(frac=0.5)

# %%
df_movies = pd.read_csv(r"D:\python-for-data-science-main\09.Merging and Concatenating DataFrames\IMDb movies.csv\IMDb movies.csv", low_memory=False)

df_left = df_movies_sample.merge(df_ratings, on='imdb_title_id', how='left')

# %%
print(df_movies_sample.shape)
print(df_ratings.shape)
print(df_left.shape)
# Out:
# (42928, 22)
# (85855, 49)
# (42928, 70)

# %%
df1.merge(df2, on='id', how='outer', indicator=True)
# Out:
#   id   age           job      _merge
# 0  A  30.0           NaN   left_only
# 1  B  23.0           NaN   left_only
# 2  C  25.0        Doctor        both
# 3  D  22.0  Statistician        both
# 4  E   NaN    Accountant  right_only
# 5  F   NaN     Developer  right_only

# %%
df1.merge(df2, on='id', how='outer', 
          indicator=True).query("_merge=='left_only'")
# Out:
#   id   age  job     _merge
# 0  A  30.0  NaN  left_only
# 1  B  23.0  NaN  left_only

# %%
df_movies_2 = df_movies.copy()

# %%
df_movies_2.index
# Out:
# RangeIndex(start=0, stop=85855, step=1)

# %%
df_movies_2.loc[0]
# Out:
# imdb_title_id                                                    tt0000009
# title                                                           Miss Jerry
# original_title                                                  Miss Jerry
# year                                                                  1894
# date_published                                                  1894-10-09
# genre                                                              Romance
# duration                                                                45
# country                                                                USA
# language                                                              None
# director                                                   Alexander Black
# writer                                                     Alexander Black
# production_company                              Alexander Black Photoplays
# actors                   Blanche Bayliss, William Courtenay, Chauncey D...
# description              The adventures of a female reporter in the 1890s.
# avg_vote                                                               5.9
# votes                                                                  154
# budget                                                                 NaN
# usa_gross_income                                                       NaN
# worlwide_gross_income                                                  NaN
# metascore                                                              NaN
# reviews_from_users                                                     1.0
# reviews_from_critics                                                   2.0
# Name: 0, dtype: object

# %%
for index in df_movies_2.index:
    if index<1000:
        df_movies_2.loc[index, 'imdb_title_id'] = 'tt1234567890'
        
df_movies_2
# Out:
#       imdb_title_id                           title  \
# 0      tt1234567890                      Miss Jerry
# 1      tt1234567890     The Story of the Kelly Gang
# 2      tt1234567890                  Den sorte drøm
# 3      tt1234567890                       Cleopatra
# 4      tt1234567890                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ...  \
# 0                          Alexander Black  ...
# 1                             Charles Tait  ...
# 2                                Urban Gad  ...
# 3                       Charles L. Gaskill  ...
# 4      Francesco Bertolini, Adolfo Padovan  ...
# ...                                    ...  ...
# 85850               Ludovic Colbeau-Justin  ...
# 85851                      Johan Nijenhuis  ...
# 85852                      Vineesh Aaradya  ...
# 85853                    Ahmet Faik Akinci  ...
# 85854                            Laura Jou  ...
#
#                                                   actors  \
# 0      Blanche Bayliss, William Courtenay, Chauncey D...
# 1      Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2      Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3      Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4      Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# ...                                                  ...
# 85850  Dany Boon, Philippe Katerine, Anne Serra, Samu...
# 85851  Herman Finkers, Johanna ter Steege, Leonie ter...
# 85852  Anoop Chandran, Indrans, Sona Nair, Simon Brit...
# 85853  Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...
# 85854  Maria Morera Colomer, Biel Rossell Pelfort, Is...
#
#                                              description avg_vote votes  \
# 0      The adventures of a female reporter in the 1890s.      5.9   154
# 1      True story of notorious Australian outlaw Ned ...      6.1   589
# 2      Two men of high rank are both wooing the beaut...      5.8   188
# 3      The fabled queen of Egypt's affair with Roman ...      5.2   446
# 4      Loosely adapted from Dante's Divine Comedy and...      7.0  2237
# ...                                                  ...      ...   ...
# 85850  A psychiatric hospital patient pretends to be ...      5.3   398
# 85851  A middle-aged veterinary surgeon believes his ...      7.7   724
# 85852                                                NaN      7.9   265
# 85853                                                NaN      6.4   194
# 85854  Pep, a 13-year-old boy, is in love with a girl...      6.7   102
#
#         budget  usa_gross_income worlwide_gross_income metascore  \
# 0          NaN               NaN                   NaN       NaN
# 1       $ 2250               NaN                   NaN       NaN
# 2          NaN               NaN                   NaN       NaN
# 3      $ 45000               NaN                   NaN       NaN
# 4          NaN               NaN                   NaN       NaN
# ...        ...               ...                   ...       ...
# 85850      NaN               NaN             $ 3507171       NaN
# 85851      NaN               NaN             $ 7299062       NaN
# 85852      NaN               NaN                   NaN       NaN
# 85853      NaN               NaN                $ 2833       NaN
# 85854      NaN               NaN               $ 59794       NaN
#
#       reviews_from_users  reviews_from_critics
# 0                    1.0                   2.0
# 1                    7.0                   7.0
# 2                    5.0                   2.0
# 3                   25.0                   3.0
# 4                   31.0                  14.0
# ...                  ...                   ...
# 85850                NaN                   4.0
# 85851                6.0                   4.0
# 85852                NaN                   NaN
# 85853                NaN                   NaN
# 85854                NaN                   2.0
#
# [85855 rows x 22 columns]

# %%
df_exclusive_left = df_movies_2.merge(df_ratings, on='imdb_title_id', how='outer', 
                                                      indicator=True).query("_merge=='left_only'")

# %%
print(df_movies_2.shape)
print(df_ratings.shape)
print(df_exclusive_left.shape)
# Out:
# (85855, 22)
# (85855, 49)
# (1000, 71)

# %%
df_ratings = pd.read_csv(r"D:\python-for-data-science-main\09.Merging and Concatenating DataFrames\IMDb ratings.csv\IMDb ratings.csv")

df_ratings_sample = df_ratings.sample(frac=0.3)
df_ratings_sample
# Out:
#       imdb_title_id  weighted_average_vote  total_votes  mean_vote  \
# 40960     tt0297871                    6.8          581        7.1
# 59261     tt1543283                    6.4          667        7.0
# 76242     tt4943992                    8.5         1114        8.8
# 64434     tt2088950                    5.6         4185        5.7
# 28976     tt0113278                    4.1         1100        6.7
# ...             ...                    ...          ...        ...
# 9613      tt0051848                    6.8         2093        6.9
# 53715     tt1087475                    2.9          105        3.0
# 2937      tt0029984                    6.9         1501        7.5
# 14977     tt0067155                    7.0          291        7.3
# 13570     tt0063169                    6.6          541        6.6
#
#        median_vote  votes_10  votes_9  votes_8  votes_7  votes_6  ...  \
# 40960          7.0        91       70      121      109       75  ...
# 59261          7.0       135       62      118      118       80  ...
# 76242         10.0       665      199       82       55       21  ...
# 64434          6.0       195      157      372      732      983  ...
# 28976          9.0       472       93       27       41       37  ...
# ...            ...       ...      ...      ...      ...      ...  ...
# 9613           7.0       118      110      352      811      431  ...
# 53715          1.0        10        1        2        3        0  ...
# 2937           8.0       270      228      256      371      203  ...
# 14977          7.0        41       40       63       74       36  ...
# 13570          7.0        44       33       91      138       93  ...
#
#        females_30age_avg_vote  females_30age_votes  females_45age_avg_vote  \
# 40960                     7.9                 23.0                     8.0
# 59261                     5.5                 19.0                     4.9
# 76242                     8.8                 34.0                     8.7
# 64434                     5.5                325.0                     5.9
# 28976                     6.3                146.0                     5.4
# ...                       ...                  ...                     ...
# 9613                      6.6                 44.0                     6.6
# 53715                     4.4                 17.0                     1.0
# 2937                      7.0                 98.0                     7.5
# 14977                     7.2                 17.0                     6.9
# 13570                     6.2                 17.0                     5.9
#
#        females_45age_votes  top1000_voters_rating  top1000_voters_votes  \
# 40960                 23.0                    4.4                  22.0
# 59261                  7.0                    5.2                  11.0
# 76242                  3.0                    5.5                  11.0
# 64434                149.0                    5.2                 126.0
# 28976                 65.0                    3.7                  49.0
# ...                    ...                    ...                   ...
# 9613                  60.0                    6.6                 181.0
# 53715                  6.0                    3.1                   7.0
# 2937                 186.0                    6.0                 133.0
# 14977                  9.0                    5.6                  30.0
# 13570                 12.0                    5.4                  48.0
#
#        us_voters_rating  us_voters_votes  non_us_voters_rating  \
# 40960               6.4             35.0                   6.8
# 59261               6.7            109.0                   6.4
# 76242               7.6             44.0                   7.9
# 64434               5.5            572.0                   5.5
# 28976               4.3            587.0                   3.5
# ...                 ...              ...                   ...
# 9613                6.9            601.0                   6.7
# 53715               2.9             55.0                   2.7
# 2937                7.2            917.0                   6.3
# 14977               7.5             30.0                   6.9
# 13570               6.6            188.0                   6.4
#
#        non_us_voters_votes
# 40960                405.0
# 59261                419.0
# 76242                310.0
# 64434               1977.0
# 28976                392.0
# ...                    ...
# 9613                 953.0
# 53715                 33.0
# 2937                 280.0
# 14977                196.0
# 13570                244.0
#
# [25756 rows x 49 columns]

# %%
df_ratings_sample.columns
# Out:
# Index(['imdb_title_id', 'weighted_average_vote', 'total_votes', 'mean_vote',
#        'median_vote', 'votes_10', 'votes_9', 'votes_8', 'votes_7', 'votes_6',
#        'votes_5', 'votes_4', 'votes_3', 'votes_2', 'votes_1',
#        'allgenders_0age_avg_vote', 'allgenders_0age_votes',
#        'allgenders_18age_avg_vote', 'allgenders_18age_votes',
#        'allgenders_30age_avg_vote', 'allgenders_30age_votes',
#        'allgenders_45age_avg_vote', 'allgenders_45age_votes',
#        'males_allages_avg_vote', 'males_allages_votes', 'males_0age_avg_vote',
#        'males_0age_votes', 'males_18age_avg_vote', 'males_18age_votes',
#        'males_30age_avg_vote', 'males_30age_votes', 'males_45age_avg_vote',
#        'males_45age_votes', 'females_allages_avg_vote',
#        'females_allages_votes', 'females_0age_avg_vote', 'females_0age_votes',
#        'females_18age_avg_vote', 'females_18age_votes',
#        'females_30age_avg_vote', 'females_30age_votes',
#        'females_45age_avg_vote', 'females_45age_votes',
#        'top1000_voters_rating', 'top1000_voters_votes', 'us_voters_rating',
#        'us_voters_votes', 'non_us_voters_rating', 'non_us_voters_votes'],
#       dtype='object')

# %%
df_right = df_movies.merge(df_ratings_sample, on='imdb_title_id', how='right')

# %%
print(df_movies.shape)
print(df_ratings_sample.shape)
print(df_right.shape)
# Out:
# (85855, 22)
# (25756, 49)
# (25756, 70)

# %%
df1.merge(df2, on='id', how='outer', indicator=True)
# Out:
#   id   age           job      _merge
# 0  A  30.0           NaN   left_only
# 1  B  23.0           NaN   left_only
# 2  C  25.0        Doctor        both
# 3  D  22.0  Statistician        both
# 4  E   NaN    Accountant  right_only
# 5  F   NaN     Developer  right_only

# %%
df1.merge(df2, on='id', how='outer', indicator=True).query("_merge=='right_only'")
# Out:
#   id  age         job      _merge
# 4  E  NaN  Accountant  right_only
# 5  F  NaN   Developer  right_only

# %%
df_ratings_2 = df_ratings.copy()

# %%
df_ratings_2.index
# Out:
# RangeIndex(start=0, stop=85855, step=1)

# %%
for index in df_ratings_2.index:
    if index <1000:
        df_ratings_2.loc[index, 'imdb_title_id'] = 'tt1234567890'

df_ratings_2
# Out:
#       imdb_title_id  weighted_average_vote  total_votes  mean_vote  \
# 0      tt1234567890                    5.9          154        5.9
# 1      tt1234567890                    6.1          589        6.3
# 2      tt1234567890                    5.8          188        6.0
# 3      tt1234567890                    5.2          446        5.3
# 4      tt1234567890                    7.0         2237        6.9
# ...             ...                    ...          ...        ...
# 85850     tt9908390                    5.3          398        5.5
# 85851     tt9911196                    7.7          724        7.9
# 85852     tt9911774                    7.9          265        7.8
# 85853     tt9914286                    6.4          194        9.4
# 85854     tt9914942                    6.7          102        6.8
#
#        median_vote  votes_10  votes_9  votes_8  votes_7  votes_6  ...  \
# 0              6.0        12        4       10       43       28  ...
# 1              6.0        57       18       58      137      139  ...
# 2              6.0         6        6       17       44       52  ...
# 3              5.0        15        8       16       62       98  ...
# 4              7.0       210      225      436      641      344  ...
# ...            ...       ...      ...      ...      ...      ...  ...
# 85850          6.0        13        9       26       65      104  ...
# 85851          8.0        65      139      288      170       42  ...
# 85852          8.0        63       29       61       61       31  ...
# 85853         10.0       176        0        2        2        1  ...
# 85854          7.0         4        4       21       35       27  ...
#
#        females_30age_avg_vote  females_30age_votes  females_45age_avg_vote  \
# 0                         5.7                 13.0                     4.5
# 1                         6.2                 23.0                     6.6
# 2                         5.8                  4.0                     6.8
# 3                         5.5                 14.0                     6.1
# 4                         7.3                 82.0                     7.4
# ...                       ...                  ...                     ...
# 85850                     5.7                 11.0                     5.0
# 85851                     8.0                 47.0                     7.3
# 85852                     NaN                  NaN                     NaN
# 85853                     NaN                  NaN                     7.0
# 85854                     6.8                  4.0                     7.5
#
#        females_45age_votes  top1000_voters_rating  top1000_voters_votes  \
# 0                      4.0                    5.7                  34.0
# 1                     14.0                    6.4                  66.0
# 2                      7.0                    5.4                  32.0
# 3                     21.0                    4.9                  57.0
# 4                     77.0                    6.9                 139.0
# ...                    ...                    ...                   ...
# 85850                  2.0                    5.5                  12.0
# 85851                 30.0                    7.0                   6.0
# 85852                  NaN                    1.0                   1.0
# 85853                  1.0                    4.0                   3.0
# 85854                  4.0                    7.0                   4.0
#
#        us_voters_rating  us_voters_votes  non_us_voters_rating  \
# 0                   6.4             51.0                   6.0
# 1                   6.0             96.0                   6.2
# 2                   6.2             31.0                   5.9
# 3                   5.5            207.0                   4.7
# 4                   7.0            488.0                   7.0
# ...                 ...              ...                   ...
# 85850               6.3             22.0                   5.3
# 85851               6.8             13.0                   7.7
# 85852               NaN              NaN                   2.0
# 85853               1.7              5.0                   5.8
# 85854               6.7             13.0                   6.7
#
#        non_us_voters_votes
# 0                     70.0
# 1                    331.0
# 2                    123.0
# 3                    105.0
# 4                   1166.0
# ...                    ...
# 85850                214.0
# 85851                388.0
# 85852                  2.0
# 85853                  5.0
# 85854                 60.0
#
# [85855 rows x 49 columns]

# %%
df_exclusive_join = df_movies.merge(df_ratings_2, on='imdb_title_id', how='outer',
                                   indicator=True).query("_merge=='right_only'")

# %%
print(df_movies.shape)
print(df_ratings_2.shape)
print(df_exclusive_join.shape)
# Out:
# (85855, 22)
# (85855, 49)
# (1000, 71)
